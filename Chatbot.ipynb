# %% [markdown]
# # NLP Chatbot

# %%
# Import libraries

import numpy as np
import random
import json
import pickle

from keras.models import Sequential, load_model
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import gradient_descent_v2

import nltk
from nltk.stem import WordNetLemmatizer

# %% [markdown]
# ## Pre-processing data

# %% [markdown]
# From the intents.json file, each tag in the intents has a pattern phrase where each word needs to be extracted out of the sentence through tokenization. In order to simplify the collection of words obtained from tokenization, lemmatization is used to reduce words into their dictionary form, e.g. break, breaks, broke, broken and breaking all reduce down to break.

# %%
# Load file
intents_file = open('intents.json').read()
intents = json.loads(intents_file)

# Tokenization

words = []
classes = []
documents = []
ignore_letters = ['!', '?', ',', '.']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        word = nltk.word_tokenize(pattern) # tokenize each word
        words.extend(word)
        documents.append((word, intent['tag'])) # add documents in the corpus
        if intent['tag'] not in classes:
            classes.append(intent['tag']) # add to classes list

# Lemmatization

wnl = WordNetLemmatizer()
lemma_words = []

for word in words:
    if word not in ignore_letters and word not in lemma_words:
        lemma_words.append(wnl.lemmatize(word.lower())) # lemmatizing each word

lemma_words = sorted(lemma_words)

classes = sorted(classes)

# %% [markdown]
# ## Training and Testing Data

# %% [markdown]
# Training and testing data are created by coverting the input pattern into numbers to allow for the application of mathematical modelling. This is done by creating a list of zeros with the same length as the total number of words. A one is set to the index corresponding to the word that is contianed in the pattern. The output is set to one for the corrsponding class that the pattern belongs to.

# %%
training = []

empty_output = np.zeros(len(classes))

for document in documents:
    bag_of_words = [] 
    word_patterns = document[0]
    word_patterns = [wnl.lemmatize(word.lower()) for word in word_patterns]
    
    for word in words:
        bag_of_words.append(1) if word in word_patterns else bag_of_words.append(0)
    
    # output is a '0' for each tag and '1' for current tag (for each pattern)
    
    output_row = list(empty_output)
    output_row[classes.index(document[1])] = 1
    training.append([bag_of_words, output_row])

random.shuffle(training)

training = np.array(training)

train_x = list(training[:,0])
train_y = list(training[:,1])
# Out:
# <ipython-input-8-d981ff7d8f42>:21: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)

# %% [markdown]
# ## Training Model

# %% [markdown]
# The model consists of 3 layers. The first layer has 128 neurons, the second has 64 neurons while the last layer has the same number of neurons as classes. Dropout layers assist with overfitting of the model while the SDG optimizer is used for fitting.

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0],),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = gradient_descent_v2.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
# Out:
# Epoch 1/200
# 10/10 [==============================] - 1s 3ms/step - loss: 2.1376 - accuracy: 0.1277
# Epoch 2/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.8542 - accuracy: 0.4043
# Epoch 3/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.7855 - accuracy: 0.4468
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.5399 - accuracy: 0.5319
# Epoch 5/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.4093 - accuracy: 0.5319
# Epoch 6/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.3612 - accuracy: 0.5532
# Epoch 7/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.2677 - accuracy: 0.5745
# Epoch 8/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.1897 - accuracy: 0.6596
# Epoch 9/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1585 - accuracy: 0.7021
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0836 - accuracy: 0.6596
# Epoch 11/200
# 10/10 [==============================] - 0s 2ms/step - loss: 1.0094 - accuracy: 0.6809
# Epoch 12/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7871 - accuracy: 0.7447
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.9568 - accuracy: 0.7021
# Epoch 14/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7564 - accuracy: 0.7872
# Epoch 15/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6272 - accuracy: 0.8298
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5089 - accuracy: 0.9149
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7036 - accuracy: 0.7660
# Epoch 18/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6886 - accuracy: 0.8085
# Epoch 19/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6087 - accuracy: 0.8085
# Epoch 20/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5308 - accuracy: 0.8298
# Epoch 21/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6566 - accuracy: 0.8298
# Epoch 22/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.7024 - accuracy: 0.7447
# Epoch 23/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5089 - accuracy: 0.8511
# Epoch 24/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4076 - accuracy: 0.8723
# Epoch 25/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.6709 - accuracy: 0.7660
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5524 - accuracy: 0.8511
# Epoch 27/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4155 - accuracy: 0.8723
# Epoch 28/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3569 - accuracy: 0.9149
# Epoch 29/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4699 - accuracy: 0.8298
# Epoch 30/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.5649 - accuracy: 0.8298
# Epoch 31/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5680 - accuracy: 0.7872
# Epoch 32/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3731 - accuracy: 0.8723
# Epoch 33/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3446 - accuracy: 0.8936
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4382 - accuracy: 0.8723
# Epoch 35/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5027 - accuracy: 0.8085
# Epoch 36/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2721 - accuracy: 0.9149
# Epoch 37/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.4428 - accuracy: 0.8936
# Epoch 38/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.2063 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.3078 - accuracy: 0.8936
# Epoch 40/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2837 - accuracy: 0.8936
# Epoch 41/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5139 - accuracy: 0.7872
# Epoch 42/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2637 - accuracy: 0.8936
# Epoch 43/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2092 - accuracy: 0.9574
# Epoch 44/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2859 - accuracy: 0.9149
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2256 - accuracy: 0.9574
# Epoch 46/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2861 - accuracy: 0.9149
# Epoch 47/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1920 - accuracy: 0.9574
# Epoch 48/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1823 - accuracy: 0.9574
# Epoch 49/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3712 - accuracy: 0.8936
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2611 - accuracy: 0.8936
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2562 - accuracy: 0.9149
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2137 - accuracy: 0.9149
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2439 - accuracy: 0.9149
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1659 - accuracy: 0.9362
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1498 - accuracy: 0.9574
# Epoch 56/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1528 - accuracy: 0.9362
# Epoch 57/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1357 - accuracy: 0.9787
# Epoch 58/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1739 - accuracy: 0.9574
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4537 - accuracy: 0.8511
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2368 - accuracy: 0.8936
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2398 - accuracy: 0.8936
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3957 - accuracy: 0.7872
# Epoch 63/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2942 - accuracy: 0.8936
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2573 - accuracy: 0.9149
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1909 - accuracy: 0.9574
# Epoch 66/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2093 - accuracy: 0.8936
# Epoch 67/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2006 - accuracy: 0.9362
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2712 - accuracy: 0.8936
# Epoch 69/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3197 - accuracy: 0.8723
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2198 - accuracy: 0.9574
# Epoch 71/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1420 - accuracy: 0.9574
# Epoch 72/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3481 - accuracy: 0.9149
# Epoch 73/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1850 - accuracy: 0.9362
# Epoch 74/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2058 - accuracy: 0.9362
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3473 - accuracy: 0.8723
# Epoch 76/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1276 - accuracy: 0.9574
# Epoch 77/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1801 - accuracy: 0.9149
# Epoch 78/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1570 - accuracy: 0.9574
# Epoch 79/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3302 - accuracy: 0.8723
# Epoch 80/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1928 - accuracy: 0.9362
# Epoch 81/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2554 - accuracy: 0.9362
# Epoch 82/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1339 - accuracy: 0.9574
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9574
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1873 - accuracy: 0.9574
# Epoch 85/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1949 - accuracy: 0.9362
# Epoch 86/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1917 - accuracy: 0.9149
# Epoch 87/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1641 - accuracy: 0.9362
# Epoch 88/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2293 - accuracy: 0.9149
# Epoch 89/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1886 - accuracy: 0.9362
# Epoch 90/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1527 - accuracy: 0.9574
# Epoch 91/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1724 - accuracy: 0.9362
# Epoch 92/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2028 - accuracy: 0.9362
# Epoch 93/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1448 - accuracy: 0.9362
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1576 - accuracy: 0.9574
# Epoch 95/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1343 - accuracy: 0.9574
# Epoch 96/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2330 - accuracy: 0.9362
# Epoch 97/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1291 - accuracy: 0.9787
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0976 - accuracy: 0.9574
# Epoch 99/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1019 - accuracy: 0.9574
# Epoch 100/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1486 - accuracy: 0.9362
# Epoch 101/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1134 - accuracy: 0.9787
# Epoch 102/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1168 - accuracy: 0.9574
# Epoch 103/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1304 - accuracy: 0.9362
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1731 - accuracy: 0.9574
# Epoch 105/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1070 - accuracy: 0.9574
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1319 - accuracy: 0.9787
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1105 - accuracy: 0.9574
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2393 - accuracy: 0.9574
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1403 - accuracy: 0.9574
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0832 - accuracy: 0.9787
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1111 - accuracy: 0.9787
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1299 - accuracy: 0.9574
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1338 - accuracy: 0.9574
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1194 - accuracy: 0.9574
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1501 - accuracy: 0.9362
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.2661 - accuracy: 0.9362
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1321 - accuracy: 0.9574
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1100 - accuracy: 0.9574
# Epoch 119/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1442 - accuracy: 0.9362
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9787
# Epoch 121/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0957 - accuracy: 0.9787
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0726 - accuracy: 0.9787
# Epoch 123/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1142 - accuracy: 0.9574
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1660 - accuracy: 0.9362
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1243 - accuracy: 0.9362
# Epoch 126/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1298 - accuracy: 0.9149
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1351 - accuracy: 0.9574
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1120 - accuracy: 0.9574
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1588 - accuracy: 0.9574
# Epoch 130/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1551 - accuracy: 0.9574
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1590 - accuracy: 0.9362
# Epoch 132/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1126 - accuracy: 0.9787
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1858 - accuracy: 0.9362
# Epoch 134/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0897 - accuracy: 0.9787
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0627 - accuracy: 0.9787
# Epoch 136/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1605 - accuracy: 0.9574
# Epoch 137/200
# 10/10 [==============================] - 0s 5ms/step - loss: 0.0874 - accuracy: 0.9574
# Epoch 138/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1243 - accuracy: 0.9787
# Epoch 139/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2021 - accuracy: 0.9362
# Epoch 140/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1218 - accuracy: 0.9362
# Epoch 141/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1089 - accuracy: 0.9574
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0593 - accuracy: 1.0000
# Epoch 143/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1261 - accuracy: 0.9574
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1465 - accuracy: 0.9362
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1266 - accuracy: 0.9362
# Epoch 146/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1431 - accuracy: 0.9787
# Epoch 147/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1342 - accuracy: 0.9362
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0906 - accuracy: 0.9787
# Epoch 149/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0792 - accuracy: 0.9787
# Epoch 150/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1132 - accuracy: 0.9574
# Epoch 151/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0989 - accuracy: 0.9574
# Epoch 152/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.9574
# Epoch 153/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1276 - accuracy: 0.9362
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0765 - accuracy: 0.9787
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9574
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0959 - accuracy: 0.9787
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1406 - accuracy: 0.9574
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0851 - accuracy: 0.9787
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1039 - accuracy: 0.9362
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1186 - accuracy: 0.9574
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0803 - accuracy: 0.9787
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1574 - accuracy: 0.9149
# Epoch 163/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1129 - accuracy: 0.9574
# Epoch 164/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1103 - accuracy: 0.9787
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0814 - accuracy: 0.9787
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1078 - accuracy: 0.9362
# Epoch 167/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1240 - accuracy: 0.9149
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1059 - accuracy: 0.9787
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1003 - accuracy: 0.9574
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0970 - accuracy: 0.9787
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1067 - accuracy: 0.9574
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1936 - accuracy: 0.9149
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1386 - accuracy: 0.9574
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1077 - accuracy: 0.9362
# Epoch 175/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0935 - accuracy: 0.9574
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0708 - accuracy: 0.9787
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1169 - accuracy: 0.9787
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1604 - accuracy: 0.9149
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2079 - accuracy: 0.9574
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0850 - accuracy: 0.9787
# Epoch 181/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1851 - accuracy: 0.9574
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1764 - accuracy: 0.9574
# Epoch 183/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1015 - accuracy: 0.9787
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0903 - accuracy: 0.9574
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1086 - accuracy: 0.9574
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0766 - accuracy: 0.9787
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1418 - accuracy: 0.9574
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1519 - accuracy: 0.9362
# Epoch 189/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1377 - accuracy: 0.9574
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1634 - accuracy: 0.9362
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0848 - accuracy: 0.9787
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0864 - accuracy: 0.9787
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1486 - accuracy: 0.9362
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1210 - accuracy: 0.9574
# Epoch 195/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1147 - accuracy: 0.9574
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0605 - accuracy: 0.9787
# Epoch 197/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0567 - accuracy: 0.9787
# Epoch 198/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0678 - accuracy: 0.9787
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0591 - accuracy: 0.9787
# Epoch 200/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9574

# %% [markdown]
# ## Chatbot Implementation

# %% [markdown]
# The chatbot implementation includes a GUI where users input phrases from which the model will predict the class for. This will determine the type of response that the chatbot will produce.

# %%
model = load_model('chatbot_model.h5')


def clean_up_sentence(sentence):
    # tokenize the pattern - splitting words into array
    sentence_words = nltk.word_tokenize(sentence)
    # stemming every word - reducing to base form
    sentence_words = [wnl.lemmatize(word.lower()) for word in sentence_words]

    return sentence_words

# return bag of words array: 0 or 1 for words that exist in sentence
def bag_of_words(sentence, words, show_details=True):
    # tokenizing patterns
    sentence_words = clean_up_sentence(sentence)
    # bag of words - vocabulary matrix
    bag = [0]*len(words)
    
    for s in sentence_words:
        for i,word in enumerate(words):
            if word == s: 
                # assign 1 if current word is in the vocabulary position
                bag[i] = 1
                if show_details:
                    print ("found in bag: %s" % word)

    return(np.array(bag))

def predict_class(sentence):
    # filter below threshold predictions
    p = bag_of_words(sentence, words,show_details=False)

    res = model.predict(np.array([p]))[0]

    ERROR_THRESHOLD = 0.25

    results = [[i,r] for i,r in enumerate(res) if r>ERROR_THRESHOLD]

    # sorting strength probability
    results.sort(key=lambda x: x[1], reverse=True)

    return_list = []

    for r in results:

        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})

    return return_list

def getResponse(ints, intents_json):

    tag = ints[0]['intent']

    list_of_intents = intents_json['intents']

    for i in list_of_intents:

        if(i['tag']== tag):

            result = random.choice(i['responses'])
            
            break
        
    return result

#Creating tkinter GUI

import tkinter

from tkinter import *

def send():

    msg = EntryBox.get("1.0",'end-1c').strip()

    EntryBox.delete("0.0",END)

    if msg != '':

        ChatBox.config(state=NORMAL)
        ChatBox.insert(END, "You: " + msg + '\n\n')
        ChatBox.config(foreground="#446665", font=("Verdana", 12 )) 

        ints = predict_class(msg)

        res = getResponse(ints, intents)

        ChatBox.insert(END, "Bot: " + res + '\n\n')           

        ChatBox.config(state=DISABLED)

        ChatBox.yview(END)

root = Tk()
root.title("Chatbot")
root.geometry("400x500")
root.resizable(width=FALSE, height=FALSE)

#Create Chat window
ChatBox = Text(root, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatBox.config(state=DISABLED)

#Bind scrollbar to Chat window
scrollbar = Scrollbar(root, command=ChatBox.yview, cursor="heart")
ChatBox['yscrollcommand'] = scrollbar.set

#Create Button to send message
SendButton = Button(root, font=("Verdana",12,'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#f9a602", activebackground="#3c9d9b",fg='#000000',
                    command= send )

#Create the box to enter message
EntryBox = Text(root, bd=0, bg="white",width="29", height="5", font="Arial")

#Place all components on the screen
scrollbar.place(x=376,y=6, height=386)
ChatBox.place(x=6,y=6, height=386, width=370)
EntryBox.place(x=128, y=401, height=90, width=265)
SendButton.place(x=6, y=401, height=90)

root.mainloop()
